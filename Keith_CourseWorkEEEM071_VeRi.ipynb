# %% [markdown]
# # Step 1: GPU Selection
# 1. Find "Edit" tab above, select "Hardware accelerator" and choose "GPU"
# 2. Run bellow command to check what GPU you got

# %%
# !nvidia-smi
# Out:
# Tue Apr 30 11:28:48 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # Step 2: Code Preparation
#
# We need to maintain our codebase with git history, so a file system (Google Drive) is needed
# 1. Select the left file icon and mount your Google Drive
# 2. Move path to Google Drive
# 3. Git clone code base

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Don't run *again

# %%
#%cd /content/drive/MyDrive/
#!git clone https://github.com/Surrey-EEEM071-CVDL/2024CourseWork.git
# Out:
# /content/drive/MyDrive
# fatal: destination path '2024CourseWork' already exists and is not an empty directory.

# %% [markdown]
# # Step 3: Data Preparation
#
# Because reading images from Google Drive is very slow, we download datasets to Colab temporary file
# 1. Install gdown
# 2. Download data
# 3. Unzip data

# %%
#https://drive.google.com/file/d/1TfGT84sEv-KBXOwi735_ECr7gjTyCJNz/view?usp=drive_link
#https://drive.google.com/file/d/1TfGT84sEv-KBXOwi735_ECr7gjTyCJNz/view?usp=sharing
#https://drive.google.com/file/d/1A6vPjc5NEWJ3QABCC2h1d7F0WpDDfTYd/view?usp=drive_link
# %cd /content
# !pip install -U --no-cache-dir gdown --pre
#!gdown --no-cookies 1A6vPjc5NEWJ3QABCC2h1d7F0WpDDfTYd
# !unzip VeRi2-EEEM071.zip

# %%
# !pip install timm
# !pip install efficientnet_pytorch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 10.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # Step 4: Training

# %%
# %cd /content/drive/MyDrive/2024CourseWork/
# Out:
# /content/drive/MyDrive/2024CourseWork

# %% [markdown]
# # Tranformer Model Training

# %%
# !STUDENT_ID=6835251 STUDENT_NAME="Keith Arogo Owino" python main.py \
-s veri \
-t veri \
-a vision_transformer \
--root /content/drive/MyDrive/DATA \
--height 224 \
--width 224 \
--optim amsgrad \
--lr 0.0003 \
--max-epoch 10 \
--stepsize 20 40 \
--train-batch-size 64 \
--test-batch-size 100 \
--save-dir logs/vision_transformer-veri
# Out:
# 2024-04-26 15:13:00.964023: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-26 15:13:00.964089: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-26 15:13:00.966323: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-26 15:13:02.793325: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Student ID:6835251
# Student name:Keith Arogo Owino
# UUID:79348aa9-65df-40c0-8443-78aa851c0894
# Experiment time:2024-04-26 15:13:04
# ...

# %% [markdown]
# # Transformer model testing

# %%
# !STUDENT_ID=6835251 STUDENT_NAME="Keith Arogo Owino" python main.py \
-s veri \
-t veri \
-a vision_transformer \
--root /content/drive/MyDrive/DATA \
--height 224 \
--width 224 \
--test-batch-size 100 \
--evaluate \
--save-dir logs/vision_transformer-veri \
--load-weights logs/vision_transformer-veri/model.pth.tar-10
# Out:
# 2024-04-26 18:56:33.277259: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-26 18:56:33.277313: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-26 18:56:33.278700: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-26 18:56:34.410190: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Student ID:6835251
# Student name:Keith Arogo Owino
# UUID:6a03b0e1-776f-419b-8005-e75735c1b727
# Experiment time:2024-04-26 18:56:35
# ...

# %% [markdown]
# # EffecientNet-B0 Training
#
# Learning rates:
#
# Default - 0.0003
#
# A) 0.0001 - Done
#
# B) 0.001 - Done
#
# C) 0.01 - Done
#
# D) 0.0005 - Current
#
# Batch Size:
#
# Default - 64
#
# A) 16 - Done
#
# B) 32 - Done
#
# C) 128 - Done
#
# D) 256**

# %%
# !STUDENT_ID=6835251 STUDENT_NAME="Keith Arogo Owino" python main_mod.py \
-s veri \
-t veri \
-a efficientnet \
--root /content \
--random-erase \
--height 224 \
--width 224 \
--optim adam \
--lr 0.0003 \
--max-epoch 8 \
--stepsize 20 40 \
--train-batch-size 128 \
--test-batch-size 100 \
--save-dir logs/effecientnet_B0-veri
# Out:
# 2024-04-30 13:06:31.380031: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 13:06:31.380081: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 13:06:31.381442: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 13:06:32.517233: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Student ID:6835251
# Student name:Keith Arogo Owino
# UUID:f8af88e0-21c7-4341-82a2-67d66d0e10e7
# Experiment time:2024-04-30 13:06:34
# ...

# %% [markdown]
# # EffecientNet-B0 Testing

# %%
# !STUDENT_ID=6835251 STUDENT_NAME="Keith Arogo Owino" python main.py \
-s veri \
-t veri \
-a efficientnet \
--root /content \
--random-erase \
--height 224 \
--width 224 \
--test-batch-size 100 \
--evaluate \
--save-dir logs/effecientnet_B0-veri \
--load-weights logs/effecientnet_B0-veri/model.pth.tar-8
# Out:
# 2024-04-30 13:49:36.382464: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 13:49:36.382513: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 13:49:36.384373: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 13:49:37.619540: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Student ID:6835251
# Student name:Keith Arogo Owino
# UUID:6b44f515-06e2-4931-a101-6093214a5b37
# Experiment time:2024-04-30 13:49:38
# ...

# %% [markdown]
# # Mobinet - Default Run

# %% [markdown]
# Learning rates:
#
# Default - 0.0003
#
# 1. 0.0001
#
# 2. 0.001
#
# 3. 0.01
#
# 4. 0.0005 - Best
#
#
# Batch Size:
#
# Default - 64
#
# 1. 16
#
# 2. 32
#
# 3. 128
#
# 4. 256

# %%
#--root /content/drive/MyDrive \

# %%
# !STUDENT_ID=6835251 STUDENT_NAME="Keith Arogo Owino" python main.py \
-s veri \
-t veri \
-a mobilenet_v3_small \
--root /content \
--height 224 \
--width 224 \
--optim amsgrad \
--lr 0.0003 \
--max-epoch 10 \
--stepsize 20 40 \
--train-batch-size 64 \
--test-batch-size 100 \
--save-dir logs/mobilenet_v3_small-veri
# Out:
# 2024-04-27 11:52:26.599023: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-27 11:52:26.599078: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-27 11:52:26.600478: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-27 11:52:27.759984: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Student ID:6835251
# Student name:Keith Arogo Owino
# UUID:ba8330fc-5715-484f-8b58-38215690a875
# Experiment time:2024-04-27 11:52:29
# ...

# %% [markdown]
# # Step 5: Test Trained Model
#
# We are now evaluating off-the-shelf ImageNet-pretrained mobilenet_v3_small

# %%
# IMPOTANT: YOU MUST UPDATE THE '--save-dir' AND '--load-weights' WITH RESPECT TO WHERE THE MODEL YOU TRAINED WAS SAVED
# AND WEHRE IT'S BEING LOADED FROM FOR EVALUATION
# !STUDENT_ID=6835251 STUDENT_NAME="Keith Arogo Owino" python main.py \
-s veri \
-t veri \
-a mobilenet_v3_small \
--root /content \
--height 224 \
--width 224 \
--test-batch-size 100 \
--evaluate \
--save-dir logs/mobilenet_v3_small-veri \
--load-weights logs/mobilenet_v3_small-veri/model.pth.tar-10
# Out:
# 2024-04-27 12:20:54.903508: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-27 12:20:54.903559: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-27 12:20:54.905007: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-27 12:20:56.051945: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Student ID:6835251
# Student name:Keith Arogo Owino
# UUID:5ea2e006-164d-4925-9faa-6eea938f9dd2
# Experiment time:2024-04-27 12:20:57
# ...
